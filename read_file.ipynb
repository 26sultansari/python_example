# %%
import pandas as pd

ufo = pd.read_csv('https://github.com/cocaineteddybear/data/blob/2341df4b8a91411191c11652deba5c5ef15d0c23/olympics.csv')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
turkce_sutun_isimleri = ['Sehir','Renk','Sekil','Eyalet','Zaman']
ufo.columns = turkce_sutun_isimleri
ufo
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-9b1b479292bc> in <module>()
#       1 turkce_sutun_isimleri = ['Sehir','Renk','Sekil','Eyalet','Zaman']
# ----> 2 ufo.columns = turkce_sutun_isimleri
#       3 ufo
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    4383         try:
#    4384             object.__getattribute__(self, name)
# -> 4385             return object.__setattr__(self, name, value)
#    4386         except AttributeError:
#    4387             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     643
#     644     def _set_axis(self, axis, labels):
# --> 645         self._data.set_axis(axis, labels)
#     646         self._clear_item_cache()
#     647
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-de189a62e7e1> in <module>()
#       1 turkce_sutun_isimleri = ['Sehir','Renk','Sekil','Eyalet','Zaman']
# ----> 2 ufo.columns = turkce_sutun_isimleri
#       3 ufo.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    4383         try:
#    4384             object.__getattribute__(self, name)
# -> 4385             return object.__setattr__(self, name, value)
#    4386         except AttributeError:
#    4387             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     643
#     644     def _set_axis(self, axis, labels):
# --> 645         self._data.set_axis(axis, labels)
#     646         self._clear_item_cache()
#     647
#
# ...

# %%
ufo
# Out:
#       State              Time
# 0        NY    6/1/1930 22:00
# 1        NJ   6/30/1930 20:00
# 2        CO   2/15/1931 14:00
# 3        KS    6/1/1931 13:00
# 4        NY   4/18/1933 19:00
# 5        ND   9/15/1934 15:30
# 6        CA    6/15/1935 0:00
# 7        MI    7/15/1936 0:00
# 8        AK  10/15/1936 17:00
# 9        OR    6/15/1937 0:00
# 10       CA   8/15/1937 21:00
# 11       AL    6/1/1939 20:00
# 12       SC   6/30/1939 20:00
# 13       IA     7/7/1939 2:00
# 14       MI    6/1/1941 13:00
# 15       CA    7/2/1941 11:30
# 16       CA    2/25/1942 0:00
# 17       GA    6/1/1942 22:30
# 18       TN    7/15/1942 1:00
# 19       AK   4/30/1943 23:00
# 20       NE    6/1/1943 15:00
# 21       LA    8/15/1943 0:00
# 22       LA    8/15/1943 0:00
# 23       KY  10/15/1943 11:00
# 24       WV    1/1/1944 10:00
# 25       CA    1/1/1944 12:00
# 26       WV    1/1/1944 12:00
# 27       NM    4/2/1944 11:00
# 28       NM    6/1/1944 12:00
# 29       UT   6/30/1944 10:00
# ...

# %%
sutun_ısım=['sehir','renk']
ufo.columns= sutun_ısım
ufo
# Out:
#       sehir              renk
# 0        NY    6/1/1930 22:00
# 1        NJ   6/30/1930 20:00
# 2        CO   2/15/1931 14:00
# 3        KS    6/1/1931 13:00
# 4        NY   4/18/1933 19:00
# 5        ND   9/15/1934 15:30
# 6        CA    6/15/1935 0:00
# 7        MI    7/15/1936 0:00
# 8        AK  10/15/1936 17:00
# 9        OR    6/15/1937 0:00
# 10       CA   8/15/1937 21:00
# 11       AL    6/1/1939 20:00
# 12       SC   6/30/1939 20:00
# 13       IA     7/7/1939 2:00
# 14       MI    6/1/1941 13:00
# 15       CA    7/2/1941 11:30
# 16       CA    2/25/1942 0:00
# 17       GA    6/1/1942 22:30
# 18       TN    7/15/1942 1:00
# 19       AK   4/30/1943 23:00
# 20       NE    6/1/1943 15:00
# 21       LA    8/15/1943 0:00
# 22       LA    8/15/1943 0:00
# 23       KY  10/15/1943 11:00
# 24       WV    1/1/1944 10:00
# 25       CA    1/1/1944 12:00
# 26       WV    1/1/1944 12:00
# 27       NM    4/2/1944 11:00
# 28       NM    6/1/1944 12:00
# 29       UT   6/30/1944 10:00
# ...

# %%
ufo.head()
# Out:
#   sehir             renk
# 0    NY   6/1/1930 22:00
# 1    NJ  6/30/1930 20:00
# 2    CO  2/15/1931 14:00
# 3    KS   6/1/1931 13:00
# 4    NY  4/18/1933 19:00

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv('PozisyonSeviyeMaas.csv')
dataset
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-c2ce3c3f7240> in <module>()
#       3 import pandas as pd
#       4
# ----> 5 dataset = pd.read_csv('PozisyonSeviyeMaas.csv')
#       6 dataset
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
import pandas as pd

oly = pd.read_csv('https://github.com/cocaineteddybear/data/blob/2341df4b8a91411191c11652deba5c5ef15d0c23/olympics.csv')
oly.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-6-46968a770384> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 oly = pd.read_csv('https://github.com/cocaineteddybear/data/blob/2341df4b8a91411191c11652deba5c5ef15d0c23/olympics.csv')
#       4 oly.head()
#
# ...

# %%
import pandas as ps
df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-36d1ee2ab4fa> in <module>()
#       1 import pandas as ps
# ----> 2 df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)
#       3 df.head()
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...
