# %%
import pandas as ps
import numpy as np
df=ps.read_csv('MOCK_DATA.csv')
df.head()
# Out:
#    id first_name last_name                       email  gender      ip_address
# 0   1   Jeanelle     Agott         jagott0@harvard.edu  Female   42.217.95.245
# 1   2      Livvy    Sinden     lsinden1@altervista.org  Female    7.30.177.220
# 2   3       Gail   Matisse   gmatisse2@hugedomains.com  Female   57.216.82.161
# 3   4     Bobbye  Mulrenan  bmulrenan3@dagondesign.com  Female     91.120.45.1
# 4   5   Bernette   Dollard          bdollard4@1688.com  Female  221.143.27.108

# %%
df.pivot_table(values ='id', index ='last_name', columns ='gender'  )
# Out:
# gender        Female   Male
# last_name
# Abraham          NaN  698.0
# Ackeroyd       671.0    NaN
# Ackland          NaN  879.0
# Ackroyd          NaN  327.0
# Adacot         910.0    NaN
# Adamec           NaN  170.0
# Agott            1.0    NaN
# Akred            NaN  454.0
# Aldwich          NaN  350.0
# Alekseev        84.0    NaN
# Aleksidze        NaN  180.0
# Alenov           NaN  300.0
# Allam          163.0    NaN
# Almak          162.0    NaN
# Alpe            53.0    NaN
# Amar             NaN   32.0
# Amberson       803.0    NaN
# Amies          953.0    NaN
# Anderson        19.0    NaN
# Andrag           NaN  406.0
# Angerstein       NaN  719.0
# Anglish          NaN  288.0
# Annandale        NaN   86.0
# Annies           NaN  182.0
# Annwyl         977.0    NaN
# Anstice          NaN  353.0
# Ansty            NaN  754.0
# Antognetti       NaN  280.0
# Antoniazzi       NaN  263.0
# Antrobus       389.0    NaN
# ...              ...    ...
# ...

# %%
df.head()
# Out:
#    id first_name last_name                       email  gender      ip_address
# 0   1   Jeanelle     Agott         jagott0@harvard.edu  Female   42.217.95.245
# 1   2      Livvy    Sinden     lsinden1@altervista.org  Female    7.30.177.220
# 2   3       Gail   Matisse   gmatisse2@hugedomains.com  Female   57.216.82.161
# 3   4     Bobbye  Mulrenan  bmulrenan3@dagondesign.com  Female     91.120.45.1
# 4   5   Bernette   Dollard          bdollard4@1688.com  Female  221.143.27.108

# %%
import pandas as pd
import numpy as np

# %%
pd.Timestamp('5/7/2018  04:15PM')
# Out:
# Timestamp('2018-05-07 16:15:00')

# %%
pd.Period('7/2018')
# Out:
# Period('2018-07', 'M')

# %%
pd.Period('5/7/2018')
# Out:
# Period('2018-05-07', 'D')

# %%
t1=pd.Series(list('123'),[pd.Timestamp('2017-11-05'), pd.Timestamp('1995-08-24'), pd.Timestamp('1980-06-27')])
t1
# Out:
# 2017-11-05    1
# 1995-08-24    2
# 1980-06-27    3
# dtype: object

# %%
type(t1.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
d1=['5 November 2017','Aug 24 , 1995','2018-07-05','21/06/80']
t3=pd.DataFrame(np.random.randint(10,100, (4,2)), index=d1, columns=list('ab'))
t3
# Out:
#                   a   b
# 5 November 2017  28  12
# Aug 24 , 1995    51  29
# 2018-07-05       73  65
# 21/06/80         72  90

# %%
t3.index = pd.to_datetime(t3.index)
t3
# Out:
#              a   b
# 2017-11-05  28  12
# 1995-08-24  51  29
# 2018-07-05  73  65
# 1980-06-21  72  90

# %%
pd.Timestamp('5/7/2018')-pd.Timestamp('02/11/2017')
# Out:
# Timedelta('450 days 00:00:00')
