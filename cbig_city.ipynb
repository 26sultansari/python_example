# %%
import openpyxl as py
import sys
import csv
import pandas as pd
import numpy as np

DIR='C:/Users/sultan/Desktop/53123,sinir-istatistikleri-2016xlsx.xlsx'

df = pd.read_excel(io='53123,sinir-istatistikleri-2016xlsx.xlsx',  sheet_name='C-Mil Göre G.Yabancı' , skiprows=2)
    
print(df)
# Out:
#                              MİLLİYET       2001       2002       2003  \
# 0                          Afganistan     4745.0     1935.0     4032.0
# 1                             Almanya  2884051.0  3481671.0  3332451.0
# 2         Amerika Birleşik Devletleri   429563.0   247631.0   222918.0
# 3                    Amerikan Samoası        NaN        NaN        NaN
# 4                             Andorra       90.0       46.0       73.0
# 5                              Angola       16.0       57.0       37.0
# 6                            Anguilla        NaN        2.0        NaN
# 7                  Antigua ve Barbuda       14.0        4.0        2.0
# 8                            Arjantin     9395.0     2890.0     6509.0
# 9                          Arnavutluk    26107.0    29221.0    32439.0
# 10                              Aruba        NaN        NaN        NaN
# 11                         Avustralya    58661.0    58678.0    56854.0
# ...

# %%
df.columns
# Out:
# Index(['MİLLİYET', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'],
#       dtype='object')

# %%
df['2001']
# Out:
# 0         4745.0
# 1      2884051.0
# 2       429563.0
# 3            NaN
# 4           90.0
# 5           16.0
# 6            NaN
# 7           14.0
# 8         9395.0
# 9        26107.0
# 10           NaN
# 11       58661.0
# 12      360363.0
# 13      177612.0
# 14         463.0
# 15        2337.0
# 16           NaN
# 17         781.0
# 18          72.0
# 19           4.0
# 20           0.0
# 21           NaN
# 22      310296.0
# 23          45.0
# 24          54.0
# 25         200.0
# 26       17163.0
# 27           2.0
# 28        3398.0
# 29         425.0
#          ...
# 208       1252.0
# 209          NaN
# 210        455.0
# 211       3049.0
# 212       9740.0
# 213         15.0
# 214          NaN
# 215         10.0
# 216        180.0
# 217      44961.0
# 218          NaN
# 219          0.0
# 220      14999.0
# 221        295.0
# 222     177245.0
# 223        495.0
# 224       1709.0
# 225      26914.0
# 226          NaN
# 227         17.0
# 228       2398.0
# ...

# %%
df= df.set_index(['MİLLİYET'])
df
# Out:
#                                        2001       2002       2003       2004  \
# MİLLİYET
# Afganistan                           4745.0     1935.0     4032.0     4243.0
# Almanya                           2884051.0  3481671.0  3332451.0  3983899.0
# Amerika Birleşik Devletleri        429563.0   247631.0   222918.0   291102.0
# Amerikan Samoası                        NaN        NaN        NaN        NaN
# Andorra                                90.0       46.0       73.0       92.0
# Angola                                 16.0       57.0       37.0       45.0
# Anguilla                                NaN        2.0        NaN        1.0
# Antigua ve Barbuda                     14.0        4.0        2.0        5.0
# Arjantin                             9395.0     2890.0     6509.0     5796.0
# Arnavutluk                          26107.0    29221.0    32439.0    44423.0
# Aruba                                   NaN        NaN        NaN        NaN
# ...

# %%
# %matplotlib inline


df.loc['Lesoto'].plot(kind='bar')

# %%
import numpy as np

sLength =len(df['2007'])
df.insert(len(df.columns), 'Ülkeler ', pd.Series(np.random.randn(sLength)) )

# %%
df.columns
# Out:
# Index(['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', 'Ülkeler '],
#       dtype='object')

# %%
df['Ülkeler '] = df.get( df['Ülkeler '] , df['2001']) + df['2002']+ df['2003']+ df['2004']+ df['2005']+ df['2006']+ df['2007']+ df['2008']+ df['2009']+ df['2010']+ df['2011']+ df['2012']+ df['2013']+ df['2014']+ df['2015']+ df['2016']
df
# Out:
#                                        2001       2002       2003       2004  \
# MİLLİYET
# Afganistan                           4745.0     1935.0     4032.0     4243.0
# Almanya                           2884051.0  3481671.0  3332451.0  3983899.0
# Amerika Birleşik Devletleri        429563.0   247631.0   222918.0   291102.0
# Amerikan Samoası                        NaN        NaN        NaN        NaN
# Andorra                                90.0       46.0       73.0       92.0
# Angola                                 16.0       57.0       37.0       45.0
# Anguilla                                NaN        2.0        NaN        1.0
# Antigua ve Barbuda                     14.0        4.0        2.0        5.0
# Arjantin                             9395.0     2890.0     6509.0     5796.0
# Arnavutluk                          26107.0    29221.0    32439.0    44423.0
# Aruba                                   NaN        NaN        NaN        NaN
# ...

# %%
df1=df.max()

# %%
df1
# Out:
# 2001         2884051.0
# 2002         3481671.0
# 2003         3332451.0
# 2004         3983899.0
# 2005         4243584.0
# 2006         3762475.0
# 2007         4149805.0
# 2008         4415525.0
# 2009         4488350.0
# 2010         4385263.0
# 2011         4826315.0
# 2012         5028745.0
# 2013         5041323.0
# 2014         5250036.0
# 2015         5580792.0
# 2016         3890074.0
# Ülkeler     68744359.0
# dtype: float64

# %%
df1=df.drop('Ülkeler ', axis=1)

# %%
df2=df1.loc[df1['2005'].idxmax()]
df2
# Out:
# 2001    2884051.0
# 2002    3481671.0
# 2003    3332451.0
# 2004    3983899.0
# 2005    4243584.0
# 2006    3762475.0
# 2007    4149805.0
# 2008    4415525.0
# 2009    4488350.0
# 2010    4385263.0
# 2011    4826315.0
# 2012    5028745.0
# 2013    5041323.0
# 2014    5250036.0
# 2015    5580792.0
# 2016    3890074.0
# Name: Almanya, dtype: float64

# %%
df3=df1.loc[df1['2005'].idxmin()]
df3
# Out:
# 2001       0.0
# 2002       7.0
# 2003       1.0
# 2004       0.0
# 2005       0.0
# 2006       1.0
# 2007       NaN
# 2008       3.0
# 2009      10.0
# 2010    2075.0
# 2011      21.0
# 2012       NaN
# 2013       8.0
# 2014       7.0
# 2015       6.0
# 2016      17.0
# Name: Batı Samoa, dtype: float64

# %%
 df.isnull().sum().sum()
# Out:
# 597

# %%
df.isnull()
# Out:
#                                    2001   2002   2003   2004   2005   2006  \
# MİLLİYET
# Afganistan                        False  False  False  False  False  False
# Almanya                           False  False  False  False  False  False
# Amerika Birleşik Devletleri       False  False  False  False  False  False
# Amerikan Samoası                   True   True   True   True  False   True
# Andorra                           False  False  False  False  False  False
# Angola                            False  False  False  False  False  False
# Anguilla                           True  False   True  False  False   True
# Antigua ve Barbuda                False  False  False  False  False  False
# Arjantin                          False  False  False  False  False  False
# Arnavutluk                        False  False  False  False  False  False
# Aruba                              True   True   True   True   True   True
# ...

# %%
df['Ülkeler '].value_counts().idxmax()
# Out:
# 39786637.0

# %%
    df1 = df.copy()
    df1 = df.groupby(['MİLLİYET'])
    ds = pd.DataFrame(columns=['Ülkeler '])
    for i, c in df1:
        ds.loc[i] = [c.sort_values(by='MİLLİYET', ascending=False)['Ülkeler '].sum()]
    top3 = ds.nlargest(4,'Ülkeler ')
    print(top3.index)
# Out:
# Index(['Almanya', 'Rusya Fed.', 'İngiltere (Birleşik Krallık)', 'Bulgaristan'], dtype='object')

# %%
    df1 = df.copy()
    df1 = df.groupby(['Ülkeler '])
    ds = pd.DataFrame(columns=['MİLLİYET'])
    for i, c in df1:
        ds.loc[i] = [c.sort_values(by='MİLLİYET', ascending=False)['Ülkeler '].sum()]
    top3 = ds.nlargest(4,'MİLLİYET')
    print(top3.index)
# Out:
# Float64Index([68744359.0, 39786637.0, 31357262.0, 21599010.0], dtype='float64')

# %%
    dx = df[['2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016']]
    dx = dx[dx['2001']!=dx['2016']]
    index = (dx.max(axis=1)-dx.min(axis=1)).idxmax()
    print(df.loc[index]['2004'])
# Out:
# 1605006.0

# %%
    dx = df[['2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016']]
    dg = dx[dx['2001']!=dx['2016']]
    index = (dg.max(axis=1)-dg.min(axis=1)).idxmax()
    print(df.iloc[index]['2004'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-8a0241a5e938> in <module>()
#       2 dg = dx[dx['2001']!=dx['2016']]
#       3 index = (dg.max(axis=1)-dg.min(axis=1)).idxmax()
# ----> 4 print(df.iloc[index]['2004'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2093         # a single integer
#    2094         else:
# -> 2095             key = self._convert_scalar_indexer(key, axis)
#    2096
#    2097             if not is_integer(key):
#
# ...

# %%
print(df[(df['2001']<155.0 ) & (df['2002'] == df['2003']) & (df['2015']>df['2014'])][['2005','2008','2003','2002']])
# Out:
#           2005   2008  2003  2002
# MİLLİYET
# Haiti     60.0  107.0  36.0  36.0
