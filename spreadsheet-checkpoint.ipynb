# %%
import xlwings as xw

xw.apps[0].Book(['C:/Users/sultan/Desktop/53123,sinir-istatistikleri-2016xlsx.xlsx'])

sht = wb.sheets['Sheet2']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-8c7fcb993a76> in <module>()
#       1 import xlwings as xw
#       2
# ----> 3 xw.apps[0].Book(['C:/Users/sultan/Desktop/53123,sinir-istatistikleri-2016xlsx.xlsx'])
#       4
#       5 sht = wb.sheets['Sheet2']
#
# ~\Anaconda3\lib\site-packages\xlwings\main.py in __getitem__(self, item)
#     140
#     141     def __getitem__(self, item):
# --> 142         return App(impl=self.impl[item])
#     143
#     144     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\xlwings\_xlwindows.py in __getitem__(self, index)
#     277     def __getitem__(self, index):
#     278         hwnds = list(get_excel_hwnds())
# --> 279         return App(xl=hwnds[index])
#     280
#     281
#
# IndexError: list index out of range

# %%
import openpyxl

def main():
    book= openpyxl.Workbook()
    book.create_sheet('Sample')
    sheet =book.get_sheet_by_name('Sample')
    sheet.cell(row=1, column=1).value = 'sample' 
    sheet.cell(row=1, column=1).font = openpyxl.styles.Font(bold=True, italic=True)
   
    book.save('C:/Users/sultan/Desktop/Sample.xlsx')
    
    
if __name__ == '__main__' :
    main()
# Out:
# C:\Users\sultan\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).

# %%
pip freeze
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip freeze
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
from openpyxl.workbook import Workbook
wb =Workbook()
wb =openpyxl.load_workbook(filename="dosya1.xlsx")
ws = wb.worksheets[0]
ws1 = wb.create_sheet("yenisekme",0)
ws['A1'] = 1
ws.append([42, 43, 44])
ws.cell(row=2, column=2).value = 2
ws.cell(row=4, column=6).value = 3 
ws1.cell(row=4, column=2).value = 23
ws1['A1'] = 11
wb.save("dosya1.xlsx")

wb.close()

# %%
for name in a.sheets_names():
    print a.sheet_by_name(name)

# %%
   from xlrd import open_workbook
    import os 
 
    wb=open_workbook(['C:/Users/sultan/Desktop/53123,sinir-istatistikleri-2016xlsx.xlsx'])
   
    for name in wb.sheets_names():
        print (wb.sheet_by_name(name))
# Out:
#   File "<ipython-input-5-dedcf53440e0>", line 2
#     import os
#     ^
# IndentationError: unexpected indent

# %%
import openpyxl as py
import sys
import csv
import pandas as pd
import numpy as np

DIR='C:/Users/sultan/Desktop/53123,sinir-istatistikleri-2016xlsx.xlsx'

def main():


    wb = py.load_workbook(filename='53123,sinir-istatistikleri-2016xlsx.xlsx')
    print (wb.get_sheet_names()),
    
    

   #  sheet = wb.get_sheet_by_name('C-Mil Göre G.Yabancı')
    # No of written Rows in sheet           
    
    df = pd.read_excel(io='53123,sinir-istatistikleri-2016xlsx.xlsx',  sheet_name='C-Mil Göre G.Yabancı' )
    
    print(df)
  #  dx=pd.read_excel(io='53123,sinir-istatistikleri-2016xlsx.xlsx', sheet_name='C-Mil Göre G.Yabancı',index_col=2)
    print('bundan sonra')
    
    print(df.iloc[4]) 
     
    print('yeni dizi')
    kitap =[]
    print(df.iloc[2])                                 
    for i in df.index(2):
            if i <= 4745:
                kitap.append('Cok Kisa')
            else:
                kitap.append('Cok Uzun')
        
    df['yeni']= kitap
    print('bundan sonra2')
    
  #  def UniqueResults ():
   #     print('içerideyim')
    #    ds = pd.DataFrame()
     #   for col in  sheet_name:
      #      S=pd.Series(df[col].unique())
       #     ds[col]=S.values
        #    print(ds.iloc[2]) 
         #   return ds
    
  
   # r = sheet_name.max_row
    # No of written Columns in sheet
   # print(r)
    #c = sheet_name.max_column
    # Reading each cell in excel    
   # print(c)

     
    
    
if __name__ == '__main__':
        main()
# Out:
# C:\Users\sultan\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning: Call to deprecated function get_sheet_names (Use wb.sheetnames).
#   del sys.path[0]
# ...
